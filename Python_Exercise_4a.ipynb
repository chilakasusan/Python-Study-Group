# %% [markdown]
# Hands-On 1 — Secure Login System

# %%
#scenario 1
username_correct = True
password_correct = True
account_locked = False

if username_correct and password_correct and not account_locked:
    print("Access Granted")
else:
    print("Access Denied")
    
 #scenario 2   
    username_correct = False
password_correct = True
account_locked = True

if username_correct and password_correct and not account_locked:
    print("Access Granted")
else:
    print("Access Denied")
# Out:
# Access Granted
# Access Denied

# %% [markdown]
# Hands-On 2 — University Scholarship Eligibility

# %%
score = 85
participated = True
low_income = False

if score >= 80 and (participated or low_income):
    print("Congratulations!")
    print("Scholarship Approved.")
else:
    print("Scholarship Not Approved.")
# Out:
# Congratulations!
# Scholarship Approved.

# %% [markdown]
# Hands-On 3 — Smart Server Health Monitor

# %%
cpu_usage = 75
memory_usage = 92
disk_usage = 60

if cpu_usage > 90 or memory_usage > 90 or disk_usage > 95:
    print("⚠️ Critical Alert!")
else:
    print("✅ System Healthy")
# Out:
# ⚠️ Critical Alert!

# %% [markdown]
# Bonus Challenge

# %%
#Scenario_1 Everything valid → Order Confirmed
logged_in = True
in_stock = True
saved_payment = False
wallet_balance_sufficient = True
account_suspended = False

order_allowed = (
    logged_in
    and in_stock
    and (saved_payment or wallet_balance_sufficient)
    and not account_suspended
)

if order_allowed:
    print("✅ Order Confirmed")
else:
    print("❌ Order Failed")
    
    
 #scenario_2 Not logged in → Order Failed
logged_in = False
in_stock = True
saved_payment = True
wallet_balance_sufficient = True
account_suspended = False


order_allowed = (
    logged_in
    and in_stock
    and (saved_payment or wallet_balance_sufficient)
    and not account_suspended
)

if order_allowed:
    print("✅ Order Confirmed")
else:
    print("❌ Order Failed")
    
    
# Scenario 3: Item out of stock → Order Failed
logged_in = True
in_stock = False
saved_payment = True
wallet_balance_sufficient = True
account_suspended = False

order_allowed = (
    logged_in
    and in_stock
    and (saved_payment or wallet_balance_sufficient)
    and not account_suspended
)

if order_allowed:
    print("✅ Order Confirmed")
else:
    print("❌ Order Failed")

# Scenario 4: No payment method AND insufficient wallet → Order Failed
logged_in = True
in_stock = True
saved_payment = False
wallet_balance_sufficient = False
account_suspended = False

order_allowed = (
    logged_in
    and in_stock
    and (saved_payment or wallet_balance_sufficient)
    and not account_suspended
)

if order_allowed:
    print("✅ Order Confirmed")
else:
    print("❌ Order Failed")

# Scenario 5: Everything fine but account suspended → Order Failed
logged_in = True
in_stock = True
saved_payment = True
wallet_balance_sufficient = True
account_suspended = True
order_allowed = (
    logged_in
    and in_stock
    and (saved_payment or wallet_balance_sufficient)
    and not account_suspended
)

if order_allowed:
    print("✅ Order Confirmed")
else:
    print("❌ Order Failed")
# Out:
# ✅ Order Confirmed
# ❌ Order Failed
# ❌ Order Failed
# ❌ Order Failed
# ❌ Order Failed
