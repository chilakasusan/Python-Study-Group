# %% [markdown]
# # Exercise 1- – Printing Text (Beginner)

# %%
print("Hello, World!")
print ("My names are Susan Osaremeh Chilaka")
print ("I am learning Python.")
print ("Programming is exciting!")
# Out:
# Hello, World!
# My names are Susan Osaremeh Chilaka
# I am learning Python.
# Programming is exciting!

# %% [markdown]
# # Exercise 2 – Multiple Print Statements (Beginner)

# %%
print("My favorite movie is The Lion King.")
# Out:
# My favorite movie is The Lion King.

# %% [markdown]
# # Exercise 3 – Python Calculator

# %%
print(15 + 5)
print(30 - 12)
print(9 * 8)
print(72/9)
print(18 % 5)
print(10 // 3)
print(5^2)
# Out:
# 20
# 18
# 72
# 8.0
# 3
# 3
# 7

# %% [markdown]
# # Exercise 4 – Understanding Comments

# %%
print("Python") #Python is the programming language i am learning at the moment.
print("Programming") #Python is a high-level programming language.
print("Lesson One") #I just started lesson one.
# Out:
# Python
# Programming
# Lesson One

# %% [markdown]
# # Exercise 5 – Mini Challenge

# %%
#Prints your name
print("My names are Susan Osaremeh Chilaka") 

#Prints your dream career
print("Climate Scientist")

#Prints your country
print("Nigeria")

#Calculates 25 + 75
print(25 + 75)

#Calculates 40 // 6
print (40 // 6)

#Calculates 8²
print (8^2)
# Out:
# My names are Susan Osaremeh Chilaka
# Climate Scientist
# Nigeria
# 100
# 6
# 10
